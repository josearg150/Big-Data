# %%
#Importamos las librerias
import pandas as pd
import numpy as np
#inmport statsmodels as ss #estadisiticas
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#leemos el dataset
data = pd.read_csv('D:\\7 Semestre\\Big Data\\Jupiter\\country_vaccinations.csv')

# %%
data
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 52734     Zimbabwe      ZWE  2021-10-17           5701675.0
# 52735     Zimbabwe      ZWE  2021-10-18           5742988.0
# 52736     Zimbabwe      ZWE  2021-10-19           5756747.0
# 52737     Zimbabwe      ZWE  2021-10-20           5780767.0
# 52738     Zimbabwe      ZWE  2021-10-21           5797283.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 52734          3221576.0                2480099.0                 13717.0
# 52735          3241469.0                2501519.0                 41313.0
# 52736          3247552.0                2509195.0                 13759.0
# 52737          3257360.0                2523407.0                 24020.0
# 52738          3264429.0                2532854.0                 16516.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 52734             17164.0                           37.78
# 52735             21169.0                           38.05
# 52736             20610.0                           38.14
# 52737             21176.0                           38.30
# 52738             20431.0                           38.41
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 52734                          21.35                                16.43
# 52735                          21.48                                16.57
# 52736                          21.52                                16.63
# 52737                          21.58                                16.72
# 52738                          21.63                                16.78
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                34.0
# 2                                34.0
# 3                                34.0
# 4                                34.0
# ...                               ...
# 52734                          1137.0
# 52735                          1403.0
# 52736                          1366.0
# 52737                          1403.0
# 52738                          1354.0
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 52734  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52735  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52736  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52737  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52738  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 52734         Ministry of Health
# 52735         Ministry of Health
# 52736         Ministry of Health
# 52737         Ministry of Health
# 52738         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 52734  https://www.arcgis.com/home/webmap/viewer.html...
# 52735  https://www.arcgis.com/home/webmap/viewer.html...
# 52736  https://www.arcgis.com/home/webmap/viewer.html...
# 52737  https://www.arcgis.com/home/webmap/viewer.html...
# 52738  https://www.arcgis.com/home/webmap/viewer.html...
#
# [52739 rows x 15 columns]

# %%
data.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
#preprocesamiento de informacion
#ejemplo de reemplazo y cambio de tipo de dato
data["date"] = data["date"].str.replace('/','-')

# %%
data
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 52734     Zimbabwe      ZWE  2021-10-17           5701675.0
# 52735     Zimbabwe      ZWE  2021-10-18           5742988.0
# 52736     Zimbabwe      ZWE  2021-10-19           5756747.0
# 52737     Zimbabwe      ZWE  2021-10-20           5780767.0
# 52738     Zimbabwe      ZWE  2021-10-21           5797283.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 52734          3221576.0                2480099.0                 13717.0
# 52735          3241469.0                2501519.0                 41313.0
# 52736          3247552.0                2509195.0                 13759.0
# 52737          3257360.0                2523407.0                 24020.0
# 52738          3264429.0                2532854.0                 16516.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 52734             17164.0                           37.78
# 52735             21169.0                           38.05
# 52736             20610.0                           38.14
# 52737             21176.0                           38.30
# 52738             20431.0                           38.41
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 52734                          21.35                                16.43
# 52735                          21.48                                16.57
# 52736                          21.52                                16.63
# 52737                          21.58                                16.72
# 52738                          21.63                                16.78
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                34.0
# 2                                34.0
# 3                                34.0
# 4                                34.0
# ...                               ...
# 52734                          1137.0
# 52735                          1403.0
# 52736                          1366.0
# 52737                          1403.0
# 52738                          1354.0
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 52734  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52735  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52736  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52737  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52738  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 52734         Ministry of Health
# 52735         Ministry of Health
# 52736         Ministry of Health
# 52737         Ministry of Health
# 52738         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 52734  https://www.arcgis.com/home/webmap/viewer.html...
# 52735  https://www.arcgis.com/home/webmap/viewer.html...
# 52736  https://www.arcgis.com/home/webmap/viewer.html...
# 52737  https://www.arcgis.com/home/webmap/viewer.html...
# 52738  https://www.arcgis.com/home/webmap/viewer.html...
#
# [52739 rows x 15 columns]

# %%
#Limpieza de la informacion
data.isnull().sum() #suma si son nulos
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     24245
# people_vaccinated                      25575
# people_fully_vaccinated                28535
# daily_vaccinations_raw                 29428
# daily_vaccinations                       262
# total_vaccinations_per_hundred         24245
# people_vaccinated_per_hundred          25575
# people_fully_vaccinated_per_hundred    28535
# daily_vaccinations_per_million           262
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
#Estadisticas : muestra los porcentajes de la informacion faltante por columna
data.isnull().sum()/data.shape[0] #shape : (rows,cols)
# Out:
# country                                0.000000
# iso_code                               0.000000
# date                                   0.000000
# total_vaccinations                     0.459717
# people_vaccinated                      0.484935
# people_fully_vaccinated                0.541061
# daily_vaccinations_raw                 0.557993
# daily_vaccinations                     0.004968
# total_vaccinations_per_hundred         0.459717
# people_vaccinated_per_hundred          0.484935
# people_fully_vaccinated_per_hundred    0.541061
# daily_vaccinations_per_million         0.004968
# vaccines                               0.000000
# source_name                            0.000000
# source_website                         0.000000
# dtype: float64

# %%
#eliminar los Nan que existen
datosLimpios = data.dropna()

# %%
datosLimpios
# Out:
#            country iso_code        date  total_vaccinations  \
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# 260        Albania      ALB  2021-02-18              3049.0
# 342        Albania      ALB  2021-05-11            622507.0
# 343        Albania      ALB  2021-05-12            632676.0
# ...            ...      ...         ...                 ...
# 52734     Zimbabwe      ZWE  2021-10-17           5701675.0
# 52735     Zimbabwe      ZWE  2021-10-18           5742988.0
# 52736     Zimbabwe      ZWE  2021-10-19           5756747.0
# 52737     Zimbabwe      ZWE  2021-10-20           5780767.0
# 52738     Zimbabwe      ZWE  2021-10-21           5797283.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 94              479574.0                 113739.0                  2859.0
# 101             481800.0                 148505.0                  4015.0
# 260               2438.0                    611.0                  1348.0
# 342             440921.0                 181586.0                  9548.0
# 343             444755.0                 187921.0                 10169.0
# ...                  ...                      ...                     ...
# 52734          3221576.0                2480099.0                 13717.0
# 52735          3241469.0                2501519.0                 41313.0
# 52736          3247552.0                2509195.0                 13759.0
# 52737          3257360.0                2523407.0                 24020.0
# 52738          3264429.0                2532854.0                 16516.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 94                 6487.0                            1.49
# 101                5285.0                            1.58
# 260                 254.0                            0.11
# 342               12160.0                           21.67
# 343               10870.0                           22.02
# ...                   ...                             ...
# 52734             17164.0                           37.78
# 52735             21169.0                           38.05
# 52736             20610.0                           38.14
# 52737             21176.0                           38.30
# 52738             20431.0                           38.41
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 94                              1.20                                 0.29
# 101                             1.21                                 0.37
# 260                             0.08                                 0.02
# 342                            15.35                                 6.32
# 343                            15.48                                 6.54
# ...                              ...                                  ...
# 52734                          21.35                                16.43
# 52735                          21.48                                16.57
# 52736                          21.52                                16.63
# 52737                          21.58                                16.72
# 52738                          21.63                                16.78
#
#        daily_vaccinations_per_million  \
# 94                              163.0
# 101                             133.0
# 260                              88.0
# 342                            4233.0
# 343                            3784.0
# ...                               ...
# 52734                          1137.0
# 52735                          1403.0
# 52736                          1366.0
# 52737                          1403.0
# 52738                          1354.0
#
#                                                 vaccines  \
# 94     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 101    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 260    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 342    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 343    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# ...                                                  ...
# 52734  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52735  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52736  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52737  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52738  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 94     World Health Organization
# 101    World Health Organization
# 260           Ministry of Health
# 342           Ministry of Health
# 343           Ministry of Health
# ...                          ...
# 52734         Ministry of Health
# 52735         Ministry of Health
# 52736         Ministry of Health
# 52737         Ministry of Health
# 52738         Ministry of Health
#
#                                           source_website
# 94                              https://covid19.who.int/
# 101                             https://covid19.who.int/
# 260    https://shendetesia.gov.al/vaksinimi-anticovid...
# 342    https://shendetesia.gov.al/vaksinimi-anticovid...
# 343    https://shendetesia.gov.al/vaksinimi-anticovid...
# ...                                                  ...
# 52734  https://www.arcgis.com/home/webmap/viewer.html...
# 52735  https://www.arcgis.com/home/webmap/viewer.html...
# 52736  https://www.arcgis.com/home/webmap/viewer.html...
# 52737  https://www.arcgis.com/home/webmap/viewer.html...
# 52738  https://www.arcgis.com/home/webmap/viewer.html...
#
# [20079 rows x 15 columns]

# %%
datosLimpios.shape
# Out:
# (20079, 15)

# %%
#revisamos los datos que quedan
datosLimpios.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
conjunto_datosLimpios = datosLimpios[["country", "date", "total_vaccinations"]]
conjunto_datosLimpios
# Out:
#            country        date  total_vaccinations
# 94     Afghanistan  2021-05-27            593313.0
# 101    Afghanistan  2021-06-03            630305.0
# 260        Albania  2021-02-18              3049.0
# 342        Albania  2021-05-11            622507.0
# 343        Albania  2021-05-12            632676.0
# ...            ...         ...                 ...
# 52734     Zimbabwe  2021-10-17           5701675.0
# 52735     Zimbabwe  2021-10-18           5742988.0
# 52736     Zimbabwe  2021-10-19           5756747.0
# 52737     Zimbabwe  2021-10-20           5780767.0
# 52738     Zimbabwe  2021-10-21           5797283.0
#
# [20079 rows x 3 columns]

# %%
#subconjunto mexico
mx = conjunto_datosLimpios.loc[conjunto_datosLimpios["country"] == "Mexico"]
mx
# Out:
#       country        date  total_vaccinations
# 30265  Mexico  2021-01-15            417375.0
# 30266  Mexico  2021-01-16            463246.0
# 30267  Mexico  2021-01-17            472142.0
# 30268  Mexico  2021-01-18            492529.0
# 30269  Mexico  2021-01-19            498122.0
# ...       ...         ...                 ...
# 30535  Mexico  2021-10-12         108947179.0
# 30541  Mexico  2021-10-18         112603277.0
# 30542  Mexico  2021-10-19         112996000.0
# 30543  Mexico  2021-10-20         113471215.0
# 30544  Mexico  2021-10-21         113957610.0
#
# [235 rows x 3 columns]

# %%
mx.dtypes
# Out:
# country                object
# date                   object
# total_vaccinations    float64
# dtype: object

# %%
#Conversion de float a int
mx["total_vaccinations"].astype(int)
# Out:
# 30265       417375
# 30266       463246
# 30267       472142
# 30268       492529
# 30269       498122
#            ...
# 30535    108947179
# 30541    112603277
# 30542    112996000
# 30543    113471215
# 30544    113957610
# Name: total_vaccinations, Length: 235, dtype: int32

# %%
mx.dtypes
# Out:
# country                object
# date                   object
# total_vaccinations    float64
# dtype: object

# %%
#Representacion visual de los datos
#ejes
x = mx["date"]
y = mx["total_vaccinations"]
#Creando el plot
plt.figure(figsize = (20,6))
plt.plot(x,y)
ax = plt.gca() #activa la proyeccion del plot para configuracion
ax.get_yaxis().get_major_formatter().set_scientific(False) #para que el eje
plt.xticks(np.arange(0, len(x), step = 20), rotation = 45)
plt.ylim(0, max(y))
plt.title("Total de vacunaciones en Mexico")
plt.xlabel("Fecha")
plt.ylabel("Vacunaciones")

plt.show()

# %%
#realizo una copia del df de datos limpios
ccDatosLimpios = datosLimpios.copy()

# %%
ccDatosLimpios
# Out:
#            country iso_code        date  total_vaccinations  \
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# 260        Albania      ALB  2021-02-18              3049.0
# 342        Albania      ALB  2021-05-11            622507.0
# 343        Albania      ALB  2021-05-12            632676.0
# ...            ...      ...         ...                 ...
# 52734     Zimbabwe      ZWE  2021-10-17           5701675.0
# 52735     Zimbabwe      ZWE  2021-10-18           5742988.0
# 52736     Zimbabwe      ZWE  2021-10-19           5756747.0
# 52737     Zimbabwe      ZWE  2021-10-20           5780767.0
# 52738     Zimbabwe      ZWE  2021-10-21           5797283.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 94              479574.0                 113739.0                  2859.0
# 101             481800.0                 148505.0                  4015.0
# 260               2438.0                    611.0                  1348.0
# 342             440921.0                 181586.0                  9548.0
# 343             444755.0                 187921.0                 10169.0
# ...                  ...                      ...                     ...
# 52734          3221576.0                2480099.0                 13717.0
# 52735          3241469.0                2501519.0                 41313.0
# 52736          3247552.0                2509195.0                 13759.0
# 52737          3257360.0                2523407.0                 24020.0
# 52738          3264429.0                2532854.0                 16516.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 94                 6487.0                            1.49
# 101                5285.0                            1.58
# 260                 254.0                            0.11
# 342               12160.0                           21.67
# 343               10870.0                           22.02
# ...                   ...                             ...
# 52734             17164.0                           37.78
# 52735             21169.0                           38.05
# 52736             20610.0                           38.14
# 52737             21176.0                           38.30
# 52738             20431.0                           38.41
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 94                              1.20                                 0.29
# 101                             1.21                                 0.37
# 260                             0.08                                 0.02
# 342                            15.35                                 6.32
# 343                            15.48                                 6.54
# ...                              ...                                  ...
# 52734                          21.35                                16.43
# 52735                          21.48                                16.57
# 52736                          21.52                                16.63
# 52737                          21.58                                16.72
# 52738                          21.63                                16.78
#
#        daily_vaccinations_per_million  \
# 94                              163.0
# 101                             133.0
# 260                              88.0
# 342                            4233.0
# 343                            3784.0
# ...                               ...
# 52734                          1137.0
# 52735                          1403.0
# 52736                          1366.0
# 52737                          1403.0
# 52738                          1354.0
#
#                                                 vaccines  \
# 94     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 101    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 260    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 342    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 343    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# ...                                                  ...
# 52734  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52735  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52736  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52737  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52738  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 94     World Health Organization
# 101    World Health Organization
# 260           Ministry of Health
# 342           Ministry of Health
# 343           Ministry of Health
# ...                          ...
# 52734         Ministry of Health
# 52735         Ministry of Health
# 52736         Ministry of Health
# 52737         Ministry of Health
# 52738         Ministry of Health
#
#                                           source_website
# 94                              https://covid19.who.int/
# 101                             https://covid19.who.int/
# 260    https://shendetesia.gov.al/vaksinimi-anticovid...
# 342    https://shendetesia.gov.al/vaksinimi-anticovid...
# 343    https://shendetesia.gov.al/vaksinimi-anticovid...
# ...                                                  ...
# 52734  https://www.arcgis.com/home/webmap/viewer.html...
# 52735  https://www.arcgis.com/home/webmap/viewer.html...
# 52736  https://www.arcgis.com/home/webmap/viewer.html...
# 52737  https://www.arcgis.com/home/webmap/viewer.html...
# 52738  https://www.arcgis.com/home/webmap/viewer.html...
#
# [20079 rows x 15 columns]

# %%
#Normalizando la informacion
#Agregamos columnas y las transformamos (las variables)
#A datos logaritimicos con base 10
# corr + fuerte
ccDatosLimpios['total_vacc'] = np.log10(ccDatosLimpios['total_vaccinations'])
ccDatosLimpios['people_vacc'] = np.log10(ccDatosLimpios['people_vaccinated'])
ccDatosLimpios['people_fully_vacc'] = np.log10(ccDatosLimpios['people_fully_vaccinated'])
ccDatosLimpios['daily_vacc'] = np.log10(ccDatosLimpios['daily_vaccinations'])
# Out:
# E:\Programas\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ccDatosLimpios['total_vacc'] = np.log10(ccDatosLimpios['total_vaccinations'])
ccDatosLimpios['people_vacc'] = np.log10(ccDatosLimpios['people_vaccinated'])
ccDatosLimpios['people_fully_vacc'] = np.log10(ccDatosLimpios['people_fully_vaccinated'])
ccDatosLimpios['daily_vacc'] = np.log10(ccDatosLimpios['daily_vaccinations'])

# %%
ccDatosLimpios.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website', 'total_vacc',
#        'people_vacc', 'people_fully_vacc', 'daily_vacc'],
#       dtype='object')

# %%
#Falta crear otro dataset para que funcione
fig, axes = plt.subplots(ncols=len(ccDatosLimpios.columns), figsize=(30,5))
for ax, col in zip(axes, ccDatosLimpios.columns):
    sns.distplot(ccDatosLimpios[col], ax = ax) 
    plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-6c3e07512a9b> in <module>
#       2 fig, axes = plt.subplots(ncols=len(ccDatosLimpios.columns), figsize=(30,5))
#       3 for ax, col in zip(axes, ccDatosLimpios.columns):
# ----> 4     sns.distplot(ccDatosLimpios[col], ax = ax)
#       5     plt.tight_layout()
#       6 plt.show()
#
# E:\Programas\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2572
#    2573     # Make a a 1-d float array
# -> 2574     a = np.asarray(a, float)
#    2575     if a.ndim > 1:
#    2576         a = a.squeeze()
#
# E:\Programas\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# E:\Programas\anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     766               dtype='datetime64[ns]')
#     767         """
# --> 768         return np.asarray(self.array, dtype)
#     769
#     770     # ----------------------------------------------------------------------
#
# E:\Programas\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# E:\Programas\anaconda3\lib\site-packages\pandas\core\arrays\numpy_.py in __array__(self, dtype)
#     201
#     202     def __array__(self, dtype=None) -> np.ndarray:
# --> 203         return np.asarray(self._ndarray, dtype=dtype)
#     204
#     205     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# E:\Programas\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'Afghanistan'

# %%
cc = ccDatosLimpios.drop(['country', 'iso_code', 'date', 'vaccines', 'source_name', 'source_website'], axis = 1)
cc = cc.replace([np.inf, -np.inf],0)

# %%
cc.columns
# Out:
# Index(['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'total_vacc', 'people_vacc', 'people_fully_vacc', 'daily_vacc'],
#       dtype='object')

# %%
#Falta crear otro dataset para que funcione
fig, axes = plt.subplots(ncols=len(cc.columns), figsize=(30,5))
for ax, col in zip(axes, cc.columns):
    sns.distplot(cc[col], ax = ax) #Hay que eliminar datos str
    plt.tight_layout()
plt.show()

# %%
#Creamos un mapa de calor para ver las correlaciones entre variables
corr = cc.corr()
fig = plt.figure(figsize = (12,10))
ax = fig.add_subplot(111)
cax = ax.matshow(corr, cmap='coolwarm', vmin=1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0, len(cc.columns), 1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)
plt.show()

# %%
tablaCorr=cc.corr(method='pearson') #relacion lineal entre dos variables
tablaCorr
# Out:
#                                      total_vaccinations  people_vaccinated  \
# total_vaccinations                             1.000000           0.986765
# people_vaccinated                              0.986765           1.000000
# people_fully_vaccinated                        0.951753           0.890279
# daily_vaccinations_raw                         0.764675           0.813698
# daily_vaccinations                             0.835583           0.887556
# total_vaccinations_per_hundred                 0.141471           0.102197
# people_vaccinated_per_hundred                  0.165640           0.131890
# people_fully_vaccinated_per_hundred            0.119616           0.075704
# daily_vaccinations_per_million                 0.024257           0.025153
# total_vacc                                     0.470131           0.449790
# people_vacc                                    0.477078           0.459987
# people_fully_vacc                              0.397803           0.374562
# daily_vacc                                     0.422516           0.418530
#
#                                      people_fully_vaccinated  \
# total_vaccinations                                  0.951753
# people_vaccinated                                   0.890279
# people_fully_vaccinated                             1.000000
# daily_vaccinations_raw                              0.615584
# daily_vaccinations                                  0.675288
# total_vaccinations_per_hundred                      0.202057
# people_vaccinated_per_hundred                       0.216670
# people_fully_vaccinated_per_hundred                 0.193377
# daily_vaccinations_per_million                      0.016455
# total_vacc                                          0.479225
# people_vacc                                         0.480108
# people_fully_vacc                                   0.417410
# daily_vacc                                          0.403395
#
#                                      daily_vaccinations_raw  \
# total_vaccinations                                 0.764675
# people_vaccinated                                  0.813698
# people_fully_vaccinated                            0.615584
# daily_vaccinations_raw                             1.000000
# daily_vaccinations                                 0.922978
# total_vaccinations_per_hundred                    -0.011333
# people_vaccinated_per_hundred                      0.023992
# people_fully_vaccinated_per_hundred               -0.046491
# daily_vaccinations_per_million                     0.088641
# total_vacc                                         0.415491
# people_vacc                                        0.432817
# people_fully_vacc                                  0.333273
# daily_vacc                                         0.456896
#
#                                      daily_vaccinations  \
# total_vaccinations                             0.835583
# people_vaccinated                              0.887556
# people_fully_vaccinated                        0.675288
# daily_vaccinations_raw                         0.922978
# daily_vaccinations                             1.000000
# total_vaccinations_per_hundred                -0.006312
# people_vaccinated_per_hundred                  0.031701
# people_fully_vaccinated_per_hundred           -0.044427
# daily_vaccinations_per_million                 0.098317
# total_vacc                                     0.447758
# people_vacc                                    0.466021
# people_fully_vacc                              0.359660
# daily_vacc                                     0.490110
#
#                                      total_vaccinations_per_hundred  \
# total_vaccinations                                         0.141471
# people_vaccinated                                          0.102197
# people_fully_vaccinated                                    0.202057
# daily_vaccinations_raw                                    -0.011333
# daily_vaccinations                                        -0.006312
# total_vaccinations_per_hundred                             1.000000
# people_vaccinated_per_hundred                              0.981483
# people_fully_vaccinated_per_hundred                        0.977746
# daily_vaccinations_per_million                             0.304560
# total_vacc                                                 0.382470
# people_vacc                                                0.326257
# people_fully_vacc                                          0.468481
# daily_vacc                                                -0.006851
#
#                                      people_vaccinated_per_hundred  \
# total_vaccinations                                        0.165640
# people_vaccinated                                         0.131890
# people_fully_vaccinated                                   0.216670
# daily_vaccinations_raw                                    0.023992
# daily_vaccinations                                        0.031701
# total_vaccinations_per_hundred                            0.981483
# people_vaccinated_per_hundred                             1.000000
# people_fully_vaccinated_per_hundred                       0.938334
# daily_vaccinations_per_million                            0.389928
# total_vacc                                                0.411446
# people_vacc                                               0.362466
# people_fully_vacc                                         0.489386
# daily_vacc                                                0.043534
#
#                                      people_fully_vaccinated_per_hundred  \
# total_vaccinations                                              0.119616
# people_vaccinated                                               0.075704
# people_fully_vaccinated                                         0.193377
# daily_vaccinations_raw                                         -0.046491
# daily_vaccinations                                             -0.044427
# total_vaccinations_per_hundred                                  0.977746
# people_vaccinated_per_hundred                                   0.938334
# people_fully_vaccinated_per_hundred                             1.000000
# daily_vaccinations_per_million                                  0.181110
# total_vacc                                                      0.340973
# people_vacc                                                     0.280923
# people_fully_vacc                                               0.439136
# daily_vacc                                                     -0.069409
#
#                                      daily_vaccinations_per_million  \
# total_vaccinations                                         0.024257
# people_vaccinated                                          0.025153
# people_fully_vaccinated                                    0.016455
# daily_vaccinations_raw                                     0.088641
# daily_vaccinations                                         0.098317
# total_vaccinations_per_hundred                             0.304560
# people_vaccinated_per_hundred                              0.389928
# people_fully_vaccinated_per_hundred                        0.181110
# daily_vaccinations_per_million                             1.000000
# total_vacc                                                 0.184942
# people_vacc                                                0.177705
# people_fully_vacc                                          0.212224
# daily_vacc                                                 0.273467
#
#                                      total_vacc  people_vacc  \
# total_vaccinations                     0.470131     0.477078
# people_vaccinated                      0.449790     0.459987
# people_fully_vaccinated                0.479225     0.480108
# daily_vaccinations_raw                 0.415491     0.432817
# daily_vaccinations                     0.447758     0.466021
# total_vaccinations_per_hundred         0.382470     0.326257
# people_vaccinated_per_hundred          0.411446     0.362466
# people_fully_vaccinated_per_hundred    0.340973     0.280923
# daily_vaccinations_per_million         0.184942     0.177705
# total_vacc                             1.000000     0.996420
# people_vacc                            0.996420     1.000000
# people_fully_vacc                      0.914554     0.889874
# daily_vacc                             0.866307     0.892747
#
#                                      people_fully_vacc  daily_vacc
# total_vaccinations                            0.397803    0.422516
# people_vaccinated                             0.374562    0.418530
# people_fully_vaccinated                       0.417410    0.403395
# daily_vaccinations_raw                        0.333273    0.456896
# daily_vaccinations                            0.359660    0.490110
# total_vaccinations_per_hundred                0.468481   -0.006851
# people_vaccinated_per_hundred                 0.489386    0.043534
# people_fully_vaccinated_per_hundred           0.439136   -0.069409
# daily_vaccinations_per_million                0.212224    0.273467
# total_vacc                                    0.914554    0.866307
# people_vacc                                   0.889874    0.892747
# people_fully_vacc                             1.000000    0.708436
# daily_vacc                                    0.708436    1.000000

# %%
cc.to_excel("cc.xlsx", sheet_name='cc', index=False)

# %%
ccDatosLimpios
# Out:
#            country iso_code        date  total_vaccinations  \
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# 260        Albania      ALB  2021-02-18              3049.0
# 342        Albania      ALB  2021-05-11            622507.0
# 343        Albania      ALB  2021-05-12            632676.0
# ...            ...      ...         ...                 ...
# 52734     Zimbabwe      ZWE  2021-10-17           5701675.0
# 52735     Zimbabwe      ZWE  2021-10-18           5742988.0
# 52736     Zimbabwe      ZWE  2021-10-19           5756747.0
# 52737     Zimbabwe      ZWE  2021-10-20           5780767.0
# 52738     Zimbabwe      ZWE  2021-10-21           5797283.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 94              479574.0                 113739.0                  2859.0
# 101             481800.0                 148505.0                  4015.0
# 260               2438.0                    611.0                  1348.0
# 342             440921.0                 181586.0                  9548.0
# 343             444755.0                 187921.0                 10169.0
# ...                  ...                      ...                     ...
# 52734          3221576.0                2480099.0                 13717.0
# 52735          3241469.0                2501519.0                 41313.0
# 52736          3247552.0                2509195.0                 13759.0
# 52737          3257360.0                2523407.0                 24020.0
# 52738          3264429.0                2532854.0                 16516.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 94                 6487.0                            1.49
# 101                5285.0                            1.58
# 260                 254.0                            0.11
# 342               12160.0                           21.67
# 343               10870.0                           22.02
# ...                   ...                             ...
# 52734             17164.0                           37.78
# 52735             21169.0                           38.05
# 52736             20610.0                           38.14
# 52737             21176.0                           38.30
# 52738             20431.0                           38.41
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 94                              1.20                                 0.29
# 101                             1.21                                 0.37
# 260                             0.08                                 0.02
# 342                            15.35                                 6.32
# 343                            15.48                                 6.54
# ...                              ...                                  ...
# 52734                          21.35                                16.43
# 52735                          21.48                                16.57
# 52736                          21.52                                16.63
# 52737                          21.58                                16.72
# 52738                          21.63                                16.78
#
#        daily_vaccinations_per_million  \
# 94                              163.0
# 101                             133.0
# 260                              88.0
# 342                            4233.0
# 343                            3784.0
# ...                               ...
# 52734                          1137.0
# 52735                          1403.0
# 52736                          1366.0
# 52737                          1403.0
# 52738                          1354.0
#
#                                                 vaccines  \
# 94     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 101    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 260    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 342    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 343    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# ...                                                  ...
# 52734  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52735  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52736  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52737  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 52738  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 94     World Health Organization
# 101    World Health Organization
# 260           Ministry of Health
# 342           Ministry of Health
# 343           Ministry of Health
# ...                          ...
# 52734         Ministry of Health
# 52735         Ministry of Health
# 52736         Ministry of Health
# 52737         Ministry of Health
# 52738         Ministry of Health
#
#                                           source_website  total_vacc  \
# 94                              https://covid19.who.int/    5.773284
# 101                             https://covid19.who.int/    5.799551
# 260    https://shendetesia.gov.al/vaksinimi-anticovid...    3.484157
# 342    https://shendetesia.gov.al/vaksinimi-anticovid...    5.794144
# 343    https://shendetesia.gov.al/vaksinimi-anticovid...    5.801181
# ...                                                  ...         ...
# 52734  https://www.arcgis.com/home/webmap/viewer.html...    6.756002
# 52735  https://www.arcgis.com/home/webmap/viewer.html...    6.759138
# 52736  https://www.arcgis.com/home/webmap/viewer.html...    6.760177
# 52737  https://www.arcgis.com/home/webmap/viewer.html...    6.761985
# 52738  https://www.arcgis.com/home/webmap/viewer.html...    6.763225
#
#        people_vacc  people_fully_vacc  daily_vacc
# 94        5.680856           5.055909    3.812044
# 101       5.682867           5.171741    3.723045
# 260       3.387034           2.786041    2.404834
# 342       5.644361           5.259082    4.084934
# 343       5.648121           5.273975    4.036230
# ...            ...                ...         ...
# 52734     6.508068           6.394469    4.234619
# 52735     6.510742           6.398204    4.325700
# 52736     6.511556           6.399534    4.314078
# 52737     6.512866           6.401987    4.325844
# 52738     6.513807           6.403610    4.310290
#
# [20079 rows x 19 columns]

# %%
ccDatosLimpios.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# total_vacc                             float64
# people_vacc                            float64
# people_fully_vacc                      float64
# daily_vacc                             float64
# dtype: object

# %%
#transformadas
ccDatosLimpios = ccDatosLimpios.drop(columns = {'total_vaccinations','people_vaccinated'})

# %%
ccDatosLimpios.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# total_vacc                             float64
# people_vacc                            float64
# people_fully_vacc                      float64
# daily_vacc                             float64
# dtype: object

# %%
import seaborn as sns
covid = ccDatosLimpios[['date','total_vacc','people_vacc','people_fully_vacc','daily_vacc']]
#sns.set_style("ticks")
sns.set(style="ticks")
#ds  = sns.load_dataset(covid19)
sns.pairplot(covid, hue ="date")#palette="pastel"

# %%
#muestra los paises y podemos seleccionar un pais
list(ccDatosLimpios.country.unique())
# Out:
# ['Afghanistan',
#  'Albania',
#  'Andorra',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belgium',
#  'Belize',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Cambodia',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Faeroe Islands',
#  'Finland',
#  'France',
#  'French Polynesia',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Malta',
#  'Mauritania',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Namibia',
#  'Nepal',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Northern Cyprus',
#  'Northern Ireland',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palestine',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'San Marino',
#  'Saudi Arabia',
#  'Scotland',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Tajikistan',
#  'Thailand',
#  'Timor',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vietnam',
#  'Wales',
#  'Zambia',
#  'Zimbabwe']

# %%
#creamos conjuntos de datos por pais , trabajamos sobre el DF de datos limpios
Mexico = datosLimpios.loc[datosLimpios["country"] == "Mexico"]
Israel = datosLimpios.loc[datosLimpios["country"] == "Israel"]
US = datosLimpios.loc[datosLimpios["country"] == "United States"]
Canada = datosLimpios.loc[datosLimpios["country"] == "Canada"]
UK = datosLimpios.loc[datosLimpios["country"] == "United Kingdom"]
China = datosLimpios.loc[datosLimpios["country"] == "China"]

# %%
#combinamos en un DF
paises = pd.concat([Mexico, Israel, US, Canada, UK, China], axis = 0)#axis = 0 renglon

# %%
paises
# Out:
#               country iso_code        date  total_vaccinations  \
# 30265          Mexico      MEX  2021-01-15        4.173750e+05
# 30266          Mexico      MEX  2021-01-16        4.632460e+05
# 30267          Mexico      MEX  2021-01-17        4.721420e+05
# 30268          Mexico      MEX  2021-01-18        4.925290e+05
# 30269          Mexico      MEX  2021-01-19        4.981220e+05
# ...               ...      ...         ...                 ...
# 50315  United Kingdom      GBR  2021-10-20        9.501453e+07
# 50316  United Kingdom      GBR  2021-10-21        9.509009e+07
# 9773            China      CHN  2021-08-26        2.003914e+09
# 9784            China      CHN  2021-09-06        2.113083e+09
# 9796            China      CHN  2021-09-18        2.174043e+09
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 30265       4.154170e+05             1.958000e+03                 87392.0
# 30266       4.610250e+05             2.221000e+03                 45871.0
# 30267       4.687080e+05             3.434000e+03                  8896.0
# 30268       4.859830e+05             6.546000e+03                 20387.0
# 30269       4.885130e+05             9.609000e+03                  5593.0
# ...                  ...                      ...                     ...
# 50315       4.955441e+07             4.546012e+07                 75445.0
# 50316       4.960314e+07             4.548695e+07                 75560.0
# 9773        1.072500e+09             8.894390e+08              15481000.0
# 9784        1.095000e+09             9.697200e+08               5638000.0
# 9796        1.100842e+09             1.022207e+09               4026000.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 30265             49987.0                            0.32
# 30266             55493.0                            0.36
# 30267             55835.0                            0.36
# 30268             57924.0                            0.38
# 30269             57892.0                            0.38
# ...                   ...                             ...
# 50315             64803.0                          139.30
# 50316             65386.0                          139.41
# 9773           13070714.0                          138.75
# 9784            8159571.0                          146.31
# 9796            4494714.0                          150.53
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 30265                           0.32                                 0.00
# 30266                           0.35                                 0.00
# 30267                           0.36                                 0.00
# 30268                           0.37                                 0.01
# 30269                           0.38                                 0.01
# ...                              ...                                  ...
# 50315                          72.65                                66.65
# 50316                          72.72                                66.69
# 9773                           74.26                                61.59
# 9784                           75.82                                67.15
# 9796                           76.22                                70.78
#
#        daily_vaccinations_per_million  \
# 30265                           384.0
# 30266                           426.0
# 30267                           429.0
# 30268                           445.0
# 30269                           444.0
# ...                               ...
# 50315                           950.0
# 50316                           959.0
# 9773                           9050.0
# 9784                           5650.0
# 9796                           3112.0
#
#                                                 vaccines  \
# 30265  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...
# 30266  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...
# 30267  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...
# 30268  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...
# 30269  CanSino, Johnson&Johnson, Moderna, Oxford/Astr...
# ...                                                  ...
# 50315       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 50316       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 9773   CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 9784   CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 9796   CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
#
#                             source_name  \
# 30265               Secretary of Health
# 30266               Secretary of Health
# 30267               Secretary of Health
# 30268               Secretary of Health
# 30269               Secretary of Health
# ...                                 ...
# 50315  Government of the United Kingdom
# 50316  Government of the United Kingdom
# 9773         National Health Commission
# 9784         National Health Commission
# 9796         National Health Commission
#
#                                           source_website
# 30265  http://www.gob.mx/cms/uploads/attachment/file/...
# 30266  http://www.gob.mx/cms/uploads/attachment/file/...
# 30267  http://www.gob.mx/cms/uploads/attachment/file/...
# 30268  http://www.gob.mx/cms/uploads/attachment/file/...
# 30269  http://www.gob.mx/cms/uploads/attachment/file/...
# ...                                                  ...
# 50315  https://coronavirus.data.gov.uk/details/vaccin...
# 50316  https://coronavirus.data.gov.uk/details/vaccin...
# 9773   http://www.nhc.gov.cn/jkj/s7915/202110/a214158...
# 9784   http://www.nhc.gov.cn/jkj/s7915/202110/a214158...
# 9796   http://www.nhc.gov.cn/jkj/s7915/202110/a214158...
#
# [1376 rows x 15 columns]

# %%
#revisamos....
paises['country'].unique()
paises.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
plt.figure(figsize = (12, 6))
plt.title("Vacunaciones por pais")
sns.scatterplot(x = paises['date'], y = paises['total_vaccinations'], hue = paises['country'])
ax = plt.gca()
ax.get_yaxis().get_major_formatter().set_scientific(False)
plt.xticks(np.arange(0, len(x), step = 10), rotation = 45)
plt.xlabel("Fecha")
plt.ylabel("Vacunaciones")
# Out:
# Text(0, 0.5, 'Vacunaciones')
